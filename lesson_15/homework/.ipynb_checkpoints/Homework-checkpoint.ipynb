# %% [markdown]
# # HOMEWORK 14
#
# In this homework we will be working with the Fashion MNIST dataset. You will be given a classifier which suffers from considerable overfitting. Your objective will be to employ regularization techniques to mitigate the overfitting problem.
#
# Let's start with the usual imports.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras import Model
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %% [markdown]
# ### Dataset
#
# The MNIST fashgion dataset [link](https://github.com/zalandoresearch/fashion-mnist) was build by Zalando Reasearch tem consists of monochrome images of different type of clothing, namely:
# * 0	T-shirt/top
# * 1	Trouser
# * 2	Pullover
# * 3	Dress
# * 4	Coat
# * 5	Sandal
# * 6	Shirt
# * 7	Sneaker
# * 8	Bag
# * 9	Ankle boot
#
# It is also one of the Keras built-in datasets. Let's load the images and quickly inspect it.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)

# %% [markdown]
# Let's visualise some random samples.

# %%
cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1

# %% [markdown]
# ### Building the Classifier
#
# We are now going to build the baseline classifier that you will use throughout this homework.

# %%
# Data normalization
x_train = x_train/255
x_test = x_test/255

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 32)        320
#
#  flatten_5 (Flatten)         (None, 25088)             0
#
#  dense_10 (Dense)            (None, 128)               3211392
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 3213002 (12.26 MB)
# Trainable params: 3213002 (12.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 [==============================] - 21s 22ms/step - loss: 0.3943 - accuracy: 0.8633 - val_loss: 0.3254 - val_accuracy: 0.8827
# Epoch 2/50
# 938/938 [==============================] - 20s 22ms/step - loss: 0.2651 - accuracy: 0.9054 - val_loss: 0.3002 - val_accuracy: 0.8923
# Epoch 3/50
# 938/938 [==============================] - 22s 23ms/step - loss: 0.2260 - accuracy: 0.9170 - val_loss: 0.3016 - val_accuracy: 0.8954
# Epoch 4/50
# 938/938 [==============================] - 22s 23ms/step - loss: 0.1949 - accuracy: 0.9286 - val_loss: 0.3043 - val_accuracy: 0.8986
# Epoch 5/50
# 938/938 [==============================] - 22s 24ms/step - loss: 0.1735 - accuracy: 0.9373 - val_loss: 0.3158 - val_accuracy: 0.8968
# Epoch 6/50
# 938/938 [==============================] - 23s 24ms/step - loss: 0.1560 - accuracy: 0.9432 - val_loss: 0.3119 - val_accuracy: 0.9029
# Epoch 7/50
# 938/938 [==============================] - 33s 35ms/step - loss: 0.1395 - accuracy: 0.9491 - val_loss: 0.3351 - val_accuracy: 0.8984
# Epoch 8/50
# 938/938 [==============================] - 34s 36ms/step - loss: 0.1294 - accuracy: 0.9526 - val_loss: 0.3499 - val_accuracy: 0.8981
# Epoch 9/50
# 938/938 [==============================] - 34s 36ms/step - loss: 0.1150 - accuracy: 0.9579 - val_loss: 0.4026 - val_accuracy: 0.8919
# Epoch 10/50
# 938/938 [==============================] - 33s 36ms/step - loss: 0.1041 - accuracy: 0.9618 - val_loss: 0.3905 - val_accuracy: 0.8978
# Epoch 11/50
# 938/938 [==============================] - 34s 36ms/step - loss: 0.
# 938/938 [==============================] - 23s 25ms/step - loss: 0.0200 - accuracy: 0.9931 - val_loss: 0.9924 - val_accuracy: 0.8864
# Epoch 37/50
# 938/938 [==============================] - 23s 25ms/step - loss: 0.0223 - accuracy: 0.9923 - val_loss: 1.0238 - val_accuracy: 0.8843
# Epoch 38/50
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0196 - accuracy: 0.9934 - val_loss: 1.0798 - val_accuracy: 0.8888
# Epoch 39/50
# 938/938 [==============================] - 36s 38ms/step - loss: 0.0180 - accuracy: 0.9937 - val_loss: 1.0925 - val_accuracy: 0.8878
# Epoch 40/50
# 938/938 [==============================] - 34s 36ms/step - loss: 0.0247 - accuracy: 0.9917 - val_loss: 1.1077 - val_accuracy: 0.8864
# Epoch 41/50
# 938/938 [==============================] - 35s 38ms/step - loss: 0.0176 - accuracy: 0.9938 - val_loss: 1.1767 - val_accuracy: 0.8804
# Epoch 42/50
# 938/938 [==============================] - 35s 38ms/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 1.1391 - val_accuracy: 0.8766
# Epoch 43/50
# 938/938 [==============================] - 31s 33ms/step - loss: 0.0215 - accuracy: 0.9919 - val_loss: 1.1399 - val_accuracy: 0.8876
# Epoch 44/50
# 938/938 [==============================] - 26s 27ms/step - loss: 0.0163 - accuracy: 0.9942 - val_loss: 1.2368 - val_accuracy: 0.8798
# Epoch 45/50
# 938/938 [==============================] - 25s 27ms/step - loss: 0.0170 - accuracy: 0.9940 - val_loss: 1.1777 - val_accuracy: 0.8889
# Epoch 46/50
# 938/938 [==============================] - 25s 26ms/step - loss: 0.0148 - accuracy: 0.9948 - val_loss: 1.2217 - val_accuracy: 0.8863
# Epoch 47/50
# 938/938 [==============================] - 24s 26ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 1.2372 - val_accuracy: 0.8820
# Epoch 48/50
# 938/938 [==============================] - 23s 24ms/step - loss: 0.0172 - accuracy: 0.9940 - val_loss: 1.2413 - val_accuracy: 0.8854
# Epoch 49/50
# 938/938 [==============================] - 34s 37ms/step - loss: 0.0159 - accuracy: 0.9946 - val_loss: 1.2670 - val_accuracy: 0.8795
# Epoch 50/50
# 938/938 [==============================] - 40s 43ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 1.2824 - val_accuracy: 0.8815

# %%
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
    
plot_history(history)
# Out:
# Train Acc      0.9953666925430298
# Validation Acc 0.8815000057220459

# %% [markdown]
# As you can see, the classifier suffers from massive overfitting. The validation accuracy is around 88% while the training accuracy is close to 1.

# %% [markdown]
# ### Combat the Overfitting!
#
# Now it is your turn. Use the classifier as a baseline, include some regularization techniques and try to improve the classification performance. You can try any techniques you might see fit, e.g.,
# * Dropout
# * Batch normalization
# * Weight regularization
# * Data augmentation
# * Early stopping
# * Pooling
# * Reducing the number of parameters (the size of the network)
# * ...
#
# There are to objective you shall fulfill in order to successfully complete this homework:
# * The validation accuracy shall be above 91%
# * Your network (with all the regularizations applied) shall **not** be larger than the baseline

# %% [markdown]
# ## Dropout

# %%
# Modify the baseline classifier in order to reduce the overfitting and make the performance more robust

inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Dropout(0.2)(net)
net = Flatten()(net)
net = Dropout(0.5)(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 32)        320
#
#  dropout_3 (Dropout)         (None, 28, 28, 32)        0
#
#  flatten_9 (Flatten)         (None, 25088)             0
#
#  dropout_4 (Dropout)         (None, 25088)             0
#
#  dense_18 (Dense)            (None, 128)               3211392
#
#  dense_19 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params:
# 938/938 [==============================] - 33s 35ms/step - loss: 0.1858 - accuracy: 0.9306 - val_loss: 0.3049 - val_accuracy: 0.9025
# Epoch 24/25
# 938/938 [==============================] - 34s 37ms/step - loss: 0.1804 - accuracy: 0.9316 - val_loss: 0.2885 - val_accuracy: 0.9051
# Epoch 25/25
# 938/938 [==============================] - 32s 34ms/step - loss: 0.1783 - accuracy: 0.9337 - val_loss: 0.2944 - val_accuracy: 0.9057

# %%
# Show the results

plot_history(history)
# Out:
# Train Acc      0.9337000250816345
# Validation Acc 0.9057000279426575

# %% [markdown]
# ## Batch normalization

# %%
from tensorflow.keras.layers.normalization import BatchNormalization

inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = BatchNormalization()(net)
net = Dropout(0.2)(net)
net = Flatten()(net)
net = BatchNormalization()(net)
net = Dropout(0.5)(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 from tensorflow.keras.layers.normalization import BatchNormalization
#       3 inputs = Input(shape=(28, 28, 1))
#       4 net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
#
# ModuleNotFoundError: No module named 'tensorflow.keras.layers.normalization'

# %%
epochs = 25
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))

# %%
plot_history(history)

# %% [markdown]
# ## Weight regularization

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, 
                kernel_initializer='ones',
                kernel_regularizer=tf.keras.regularizers.L1(0.01),
                activity_regularizer=tf.keras.regularizers.L2(0.01))(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 32)        320
#
#  flatten_19 (Flatten)        (None, 25088)             0
#
#  dense_38 (Dense)            (None, 128)               3211392
#
#  dense_39 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 3213002 (12.26 MB)
# Trainable params: 3213002 (12.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 25
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/25
# 938/938 [==============================] - 19s 20ms/step - loss: 16.3844 - accuracy: 0.1199 - val_loss: 11.9273 - val_accuracy: 0.1357
# Epoch 2/25
# 938/938 [==============================] - 20s 21ms/step - loss: 9.5426 - accuracy: 0.1347 - val_loss: 5.8940 - val_accuracy: 0.1657
# Epoch 3/25
# 938/938 [==============================] - 19s 20ms/step - loss: 4.3746 - accuracy: 0.1642 - val_loss: 3.4875 - val_accuracy: 0.1327
# Epoch 4/25
# 938/938 [==============================] - 19s 20ms/step - loss: 3.4042 - accuracy: 0.1183 - val_loss: 3.0923 - val_accuracy: 0.1022
# Epoch 5/25
# 938/938 [==============================] - 19s 20ms/step - loss: 2.9123 - accuracy: 0.1091 - val_loss: 2.7986 - val_accuracy: 0.1080
# Epoch 6/25
# 938/938 [==============================] - 19s 20ms/step - loss: 2.6903 - accuracy: 0.1068 - val_loss: 2.6167 - val_accuracy: 0.1039
# Epoch 7/25
# 938/938 [==============================] - 20s 21ms/step - loss: 2.5219 - accuracy: 0.1109 - val_loss: 2.4828 - val_accuracy: 0.1050
# Epoch 8/25
# 938/938 [==============================] - 19s 21ms/step - loss: 2.4866 - accuracy: 0.1126 - val_loss: 2.4301 - val_accuracy: 0.1174
# Epoch 9/25
# 938/938 [==============================] - 19s 20ms/step - loss: 2.3867 - accuracy: 0.1178 - val_loss: 2.3985 - val_accuracy: 0.1074
# Epoch 10/25
# 938/938 [==============================] - 19s 21ms/step - loss: 2.3581 - accuracy: 0.1121 - val_loss: 2.3203 - val_accuracy: 0.1218
# Epoch 11/25
# 938/938 [==============================] - 19s 20ms/step - loss: 2.3105 - accuracy: 0.1186 - val_loss: 2.3297 - val_accuracy: 0.1060
# Epoch 12/25
# 938/938 [==============================] - 20s 21ms/step - loss: 2.3479 - accuracy: 0.1054 - val_loss: 2.3455 - val_accuracy: 0.1080
# Epoch 13/25
# 938/938 [==============================] - 20s 21ms/step - loss: 2.3409 - accuracy: 0.1067 - val_loss: 2.3357 - val_accuracy: 0.1059
# Epoch 14/25
# 938/938 [==============================] - 19s 21ms/step - loss: 2.3568 - accuracy: 0.1082 - val_loss: 2.4168 - val_accuracy: 0.1008
# Epoch 15/25
# 938/938 [==============================] - 19s 20ms/step - loss: 2.4346 - accuracy: 0.1005 - val_loss: 2.4315 - val_accuracy: 0.0859
# Epoch 16/25
# 938/938 [==============================] - 19s 21ms/step - loss: 2.4555 - accuracy: 0.0959 - val_loss: 2.4894 - val_accuracy: 0.1000
# Epoch 17/25
# 938/938 [==============================] - 19s 20ms/step - loss: 2.4938 - accuracy: 0.1000 - val_loss: 2.4690 - val_accuracy: 0.1000
# Epoch 18/25
# 938/938 [==============================] - 19s 21ms/step - loss: 2.4424 - accuracy: 0.1001 - val_loss: 2.4191 - val_accuracy: 0.1001
# Epoch 19/25
# 938/938 [==============================] - 21s 22ms/step - loss: 2.4017 - accuracy: 0.1000 - val_loss: 2.3846 - val_accuracy: 0.1000
# Epoch 20/25
# 938/938 [==============================] - 19s 20ms/step - loss: 2.3700 - accuracy: 0.1000 - val_loss: 2.3561 - val_accuracy: 0.1000
# Epoch 21/25
# 938/938 [==============================] - 19s 21ms/step - loss: 2.4568 - accuracy: 0.1013 - val_loss: 2.4050 - val_accuracy: 0.1012
# Epoch 22/25
# 938/938 [==============================] - 20s 21ms/step - loss: 2.3824 - accuracy: 0.1045 - val_loss: 2.3638 - val_accuracy: 0.1032
# Epoch 23/25
# 938/938 [==============================] - 19s 21ms/step - loss: 2.3521 - accuracy: 0.1038 - val_loss: 2.4077 - val_accuracy: 0.0982
# Epoch 24/25
# 938/938 [==============================] - 19s 21ms/step - loss: 2.3501 - accuracy: 0.1013 - val_loss: 2.3355 - val_accuracy: 0.1001
# Epoch 25/25
# 938/938 [==============================] - 19s 20ms/step - loss: 2.3397 - accuracy: 0.0998 - val_loss: 2.3602 - val_accuracy: 0.1000

# %%
plot_history(history)
# Out:
# Train Acc      0.09983333200216293
# Validation Acc 0.10000000149011612

# %% [markdown]
# ## Data augmentation

# %%
from sklearn.utils import shuffle

def datagen(x, y, batch_size):
    num_samples = len(y)
    while True:
        for idx in range(0, num_samples, batch_size):
            x_ = x[idx:idx + batch_size, ...]
            y_ = y[idx:idx + batch_size]
            
            if len(y_) < batch_size:
                x, y = shuffle(x, y)
                break
            
            # Augmentation
            for idx_aug in range(batch_size):
                if np.random.rand() > 0.5:
                    x_[idx_aug, ...] = np.fliplr(x_[idx_aug, ...])                                
                    
            yield x_, y_

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_17 (Conv2D)          (None, 28, 28, 32)        320
#
#  flatten_16 (Flatten)        (None, 25088)             0
#
#  dense_32 (Dense)            (None, 128)               3211392
#
#  dense_33 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 3213002 (12.26 MB)
# Trainable params: 3213002 (12.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 25
batch_size = 64
steps_per_epoch = len(y_train) // batch_size
generator = datagen(x_train, y_train, batch_size)
print(x_train.shape)

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

history = model.fit(generator, steps_per_epoch=steps_per_epoch, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# (60000, 28, 28)
# Epoch 1/25
# 937/937 [==============================] - 21s 21ms/step - loss: 0.4214 - accuracy: 0.8530 - val_loss: 0.3786 - val_accuracy: 0.8681
# Epoch 2/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.2983 - accuracy: 0.8939 - val_loss: 0.3254 - val_accuracy: 0.8856
# Epoch 3/25
# 937/937 [==============================] - 21s 22ms/step - loss: 0.2613 - accuracy: 0.9057 - val_loss: 0.3077 - val_accuracy: 0.8866
# Epoch 4/25
# 937/937 [==============================] - 20s 22ms/step - loss: 0.2387 - accuracy: 0.9149 - val_loss: 0.2990 - val_accuracy: 0.8970
# Epoch 5/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.2249 - accuracy: 0.9198 - val_loss: 0.3022 - val_accuracy: 0.8950
# Epoch 6/25
# 937/937 [==============================] - 23s 24ms/step - loss: 0.2087 - accuracy: 0.9256 - val_loss: 0.2978 - val_accuracy: 0.9004
# Epoch 7/25
# 937/937 [==============================] - 20s 22ms/step - loss: 0.1961 - accuracy: 0.9291 - val_loss: 0.3058 - val_accuracy: 0.8992
# Epoch 8/25
# 937/937 [==============================] - 21s 23ms/step - loss: 0.1866 - accuracy: 0.9320 - val_loss: 0.3017 - val_accuracy: 0.8998
# Epoch 9/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1739 - accuracy: 0.9366 - val_loss: 0.3208 - val_accuracy: 0.8962
# Epoch 10/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1634 - accuracy: 0.9406 - val_loss: 0.3457 - val_accuracy: 0.8937
# Epoch 11/25
# 937/937 [==============================] - 20s 22ms/step - loss: 0.1588 - accuracy: 0.9425 - val_loss: 0.3180 - val_accuracy: 0.9036
# Epoch 12/25
# 937/937 [==============================] - 20s 22ms/step - loss: 0.1501 - accuracy: 0.9461 - val_loss: 0.3581 - val_accuracy: 0.8973
# Epoch 13/25
# 937/937 [==============================] - 19s 21ms/step - loss: 0.1434 - accuracy: 0.9483 - val_loss: 0.3523 - val_accuracy: 0.8954
# Epoch 14/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1379 - accuracy: 0.9501 - val_loss: 0.3711 - val_accuracy: 0.8947
# Epoch 15/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1297 - accuracy: 0.9518 - val_loss: 0.3530 - val_accuracy: 0.9028
# Epoch 16/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1265 - accuracy: 0.9546 - val_loss: 0.3630 - val_accuracy: 0.9008
# Epoch 17/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1185 - accuracy: 0.9574 - val_loss: 0.3947 - val_accuracy: 0.8952
# Epoch 18/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1144 - accuracy: 0.9583 - val_loss: 0.3909 - val_accuracy: 0.8995
# Epoch 19/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1105 - accuracy: 0.9602 - val_loss: 0.3984 - val_accuracy: 0.8992
# Epoch 20/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1076 - accuracy: 0.9617 - val_loss: 0.4007 - val_accuracy: 0.8994
# Epoch 21/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1023 - accuracy: 0.9631 - val_loss: 0.4144 - val_accuracy: 0.8980
# Epoch 22/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1003 - accuracy: 0.9633 - val_loss: 0.4309 - val_accuracy: 0.8948
# Epoch 23/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.0955 - accuracy: 0.9650 - val_loss: 0.4325 - val_accuracy: 0.8957
# Epoch 24/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.0912 - accuracy: 0.9665 - val_loss: 0.4793 - val_accuracy: 0.8939
# Epoch 25/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.0886 - accuracy: 0.9676 - val_loss: 0.4662 - val_accuracy: 0.8963

# %%
plot_history(history)
# Out:
# Train Acc      0.9676327109336853
# Validation Acc 0.8963000178337097

# %% [markdown]
# ## Early stopping

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_19 (Conv2D)          (None, 28, 28, 32)        320
#
#  flatten_18 (Flatten)        (None, 25088)             0
#
#  dense_36 (Dense)            (None, 128)               3211392
#
#  dense_37 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 3213002 (12.26 MB)
# Trainable params: 3213002 (12.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 25
batch_size = 64
steps_per_epoch = len(y_train) // batch_size
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

history = model.fit(generator, steps_per_epoch=steps_per_epoch, epochs=epochs, validation_data=(x_test, y_test), callbacks=[callback])
# Out:
# Epoch 1/25
# 937/937 [==============================] - 21s 22ms/step - loss: 0.4542 - accuracy: 0.8465 - val_loss: 0.3754 - val_accuracy: 0.8655
# Epoch 2/25
# 937/937 [==============================] - 20s 22ms/step - loss: 0.3063 - accuracy: 0.8910 - val_loss: 0.3191 - val_accuracy: 0.8888
# Epoch 3/25
# 937/937 [==============================] - 20s 22ms/step - loss: 0.2690 - accuracy: 0.9041 - val_loss: 0.3256 - val_accuracy: 0.8834
# Epoch 4/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.2441 - accuracy: 0.9116 - val_loss: 0.3009 - val_accuracy: 0.8934
# Epoch 5/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.2268 - accuracy: 0.9190 - val_loss: 0.3061 - val_accuracy: 0.8967
# Epoch 6/25
# 937/937 [==============================] - 22s 24ms/step - loss: 0.2132 - accuracy: 0.9225 - val_loss: 0.3133 - val_accuracy: 0.8869
# Epoch 7/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.2019 - accuracy: 0.9278 - val_loss: 0.2932 - val_accuracy: 0.9010
# Epoch 8/25
# 937/937 [==============================] - 23s 24ms/step - loss: 0.1877 - accuracy: 0.9324 - val_loss: 0.3053 - val_accuracy: 0.8990
# Epoch 9/25
# 937/937 [==============================] - 21s 22ms/step - loss: 0.1765 - accuracy: 0.9366 - val_loss: 0.3077 - val_accuracy: 0.9009
# Epoch 10/25
# 937/937 [==============================] - 21s 22ms/step - loss: 0.1694 - accuracy: 0.9383 - val_loss: 0.3129 - val_accuracy: 0.8976
# Epoch 11/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1595 - accuracy: 0.9419 - val_loss: 0.3422 - val_accuracy: 0.8939
# Epoch 12/25
# 937/937 [==============================] - 19s 21ms/step - loss: 0.1518 - accuracy: 0.9447 - val_loss: 0.3314 - val_accuracy: 0.8985
# Epoch 13/25
# 937/937 [==============================] - 19s 20ms/step - loss: 0.1440 - accuracy: 0.9474 - val_loss: 0.3335 - val_accuracy: 0.8996
# Epoch 14/25
# 937/937 [==============================] - 19s 21ms/step - loss: 0.1352 - accuracy: 0.9513 - val_loss: 0.3543 - val_accuracy: 0.8984
# Epoch 15/25
# 937/937 [==============================] - 19s 21ms/step - loss: 0.1326 - accuracy: 0.9522 - val_loss: 0.3483 - val_accuracy: 0.9028
# Epoch 16/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1242 - accuracy: 0.9548 - val_loss: 0.3665 - val_accuracy: 0.8936
# Epoch 17/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1189 - accuracy: 0.9567 - val_loss: 0.3792 - val_accuracy: 0.8987
# Epoch 18/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1141 - accuracy: 0.9592 - val_loss: 0.3882 - val_accuracy: 0.8981
# Epoch 19/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1082 - accuracy: 0.9616 - val_loss: 0.3993 - val_accuracy: 0.8919
# Epoch 20/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1050 - accuracy: 0.9622 - val_loss: 0.4110 - val_accuracy: 0.8906
# Epoch 21/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.1000 - accuracy: 0.9633 - val_loss: 0.4235 - val_accuracy: 0.8972
# Epoch 22/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.0986 - accuracy: 0.9640 - val_loss: 0.4455 - val_accuracy: 0.8919
# Epoch 23/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.0918 - accuracy: 0.9669 - val_loss: 0.4359 - val_accuracy: 0.8946
# Epoch 24/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.0901 - accuracy: 0.9672 - val_loss: 0.4667 - val_accuracy: 0.8956
# Epoch 25/25
# 937/937 [==============================] - 20s 21ms/step - loss: 0.0891 - accuracy: 0.9673 - val_loss: 0.4534 - val_accuracy: 0.8968

# %%
plot_history(history)
# Out:
# Train Acc      0.967299222946167
# Validation Acc 0.8967999815940857

# %% [markdown]
# ## Pooling

# %%
inputs = Input(shape=(28, 28, 1))

net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = AveragePooling2D(pool_size=(2, 2))(net)
net = Dropout(0.2)(net)
net = Conv2D(64, kernel_size=(3, 3), activation="relu", padding='same')(net)
net = AveragePooling2D(pool_size=(2, 2))(net)
net = Dropout(0.2)(net)
net = Conv2D(128, kernel_size=(3, 3), activation="relu", padding='same')(net)
net = AveragePooling2D(pool_size=(2, 2))(net)
net = Dropout(0.2)(net)
net = Flatten()(net)
net = Dense(64, activation="relu")(net)
net = Dropout(0.5)(net)
outputs = Dense(1, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_37 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_18 (MaxPooli  (None, 14, 14, 32)        0
#  ng2D)
#
#  flatten_25 (Flatten)        (None, 6272)              0
#
#  dense_50 (Dense)            (None, 128)               802944
#
#  dense_51 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 803393 (3.06 MB)
# Trainable params: 803393 (3.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 25
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/25
# 2023-07-21 17:50:27.937184: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at sparse_xent_op.cc:103 : INVALID_ARGUMENT: Received a label value of 9 which is outside the valid range of [0, 1).  Label values: 0 0 6 9 5 1 4 5 8 9 3 5 2 4 0 4 3 3 5 2 5 9 4 2 7 4 6 3 1 3 6 2 3 1 5 6 1 5 9 2 5 6 4 2 5 2 2 7 2 3 7 3 1 1 4 3 1 4 3 7 0 6 4 2
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Input In [77], in <cell line: 6>()
#       2 batch_size = 64
#       4 model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
# ----> 6 history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#       app.start()
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 677, in start
#       self.io_loop.start()
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#       self._run_once()
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#       handle._run()
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_queue
#       await self.process_one()
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 460, in process_one
#       await dispatch(*args)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 367, in dispatch_shell
#       await result
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 662, in execute_request
#       reply_content = await reply_content
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 360, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2863, in run_cell
#       result = self._run_cell(
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2909, in _run_cell
#       return runner(coro)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3106, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3309, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_3412282/2749039998.py", line 6, in <cell line: 6>
#       history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/keras/src/engine/training.py", line 1742, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/keras/src/engine/training.py", line 1338, in train_function
#       return step_function(self, iterator)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/keras/src/engine/training.py", line 1322, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/keras/src/engine/training.py", line 1303, in run_step
#       outputs = model.train_step(data)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/keras/src/engine/training.py", line 1081, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/keras/src/engine/training.py", line 1139, in compute_loss
#       return self.compiled_loss(
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/keras/src/engine/compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/keras/src/losses.py", line 142, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/keras/src/losses.py", line 268, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/keras/src/losses.py", line 2354, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "/home/olenabiryukova/anaconda3/lib/python3.9/site-packages/keras/src/backend.py", line 5762, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# Received a label value of 9 which is outside the valid range of [0, 1).  Label values: 0 0 6 9 5 1 4 5 8 9 3 5 2 4 0 4 3 3 5 2 5 9 4 2 7 4 6 3 1 3 6 2 3 1 5 6 1 5 9 2 5 6 4 2 5 2 2 7 2 3 7 3 1 1 4 3 1 4 3 7 0 6 4 2
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]] [Op:__inference_train_function_1462798]

# %%
plot_history(history)

# %% [markdown]
# ## Reducing the number of parameters (the size of the network)

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(64)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()

# %%
epochs = 25
batch_size = 64
steps_per_epoch = len(y_train) // batch_size

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

history = model.fit(generator, steps_per_epoch=steps_per_epoch, epochs=epochs, validation_data=(x_test, y_test))

# %%
plot_history(history)

# %% [markdown]
# ### Questions
#
# * What have you done in order to improve the performance?
# * Have you tried configurations that did not work out?
